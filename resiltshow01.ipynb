# %%
import pandas as pd

df = pd.read_csv(".\\tdata\\DNNHidden1.tsv", sep="\t")
print(df)
# Out:
#       loss  accuracy  val_loss  val_accuracy
# 0   2.7100    0.5098    1.7221        0.6385
# 1   1.3381    0.7103    1.2633        0.7213
# 2   0.9396    0.7993    1.1040        0.7667
# 3   0.6989    0.8557    1.0250        0.7743
# 4   0.5288    0.8923    0.9734        0.7934
# 5   0.4071    0.9183    0.9576        0.7907
# 6   0.3176    0.9316    0.9553        0.8001
# 7   0.2581    0.9429    0.9756        0.7925
# 8   0.2198    0.9478    0.9791        0.7947
# 9   0.1948    0.9532    1.0036        0.7925
# 10  0.1702    0.9530    1.0227        0.7961
# 11  0.1565    0.9547    1.0310        0.7992
# 12  0.1486    0.9562    1.0638        0.8010
# 13  0.1411    0.9576    1.0733        0.7965
# 14  0.1322    0.9559    1.0860        0.7952
# 15  0.1354    0.9571    1.1316        0.7894
# 16  0.1284    0.9561    1.1253        0.7974
# 17  0.1258    0.9568    1.1515        0.7850
# 18  0.1268    0.9569    1.1299        0.7934
# 19  0.1240    0.9574    1.1639        0.7921

# %% [markdown]
# 연습

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(df['loss'], 'b-', label='loss')
plt.plot(df['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(df['accuracy'], 'g-', label='accuracy')
plt.plot(df['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %%
Group = ['E1_G6', 'E2_G11', 'E3_G20']
Group_values = [0.918, 0.891, 0.857]

plt.figure(figsize=(7, 5))
plt.bar(Group, Group_values, color='g', alpha=0.6)

for i, name in enumerate(Group):
    plt.text(name, Group_values[i], "{:.3f}".format(Group_values[i]),
             fontsize = 14, 
             color='blue',
             horizontalalignment='center',
             verticalalignment='bottom')

plt.ylim(0.7, 1.0)

plt.show()

# %%
import matplotlib.pyplot as plt
Group = ['Basic NN','Basic CNN', 'CNN_BN', 'CNN_Droupout']
Group_values = [0.751, 0.788, 0.801, 0.823]

plt.figure(figsize=(7, 5))
plt.bar(Group, Group_values, color='g', alpha=0.6)

for i, name in enumerate(Group):
    plt.text(name, Group_values[i], "{:.3f}".format(Group_values[i]),
             fontsize = 14, 
             color='blue',
             horizontalalignment='center',
             verticalalignment='bottom')

plt.ylim(0.5, 1.0)

plt.show()
