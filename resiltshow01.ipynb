# %%
import pandas as pd

df = pd.read_csv("sample.tsv", sep="\t")
print(df)
# Out:
#       loss  accuracy  val_loss  val_accuracy
# 0   2.9807    0.0741    2.8306        0.2329
# 1   2.9807    0.0741    2.8306        0.2329
# 2   2.6382    0.2339    1.6461        0.6306
# 3   2.6382    0.2339    1.6461        0.6306
# 4   1.4522    0.5858    0.8700        0.7923
# 5   1.4522    0.5858    0.8700        0.7923
# 6   0.7251    0.8076    0.5956        0.8480
# 7   0.7251    0.8076    0.5956        0.8480
# 8   0.3829    0.9097    0.4912        0.8652
# 9   0.3829    0.9097    0.4912        0.8652
# 10  0.2180    0.9508    0.4565        0.8745
# 11  0.2180    0.9508    0.4565        0.8745
# 12  0.1340    0.9704    0.4310        0.8856
# 13  0.1340    0.9704    0.4310        0.8856
# 14  0.0939    0.9783    0.4436        0.8869
# 15  0.0939    0.9783    0.4436        0.8869
# 16  0.0642    0.9877    0.4491        0.8864
# 17  0.0642    0.9877    0.4491        0.8864
# 18  0.0478    0.9912    0.4522        0.8931
# 19  0.0478    0.9912    0.4522        0.8931

# %% [markdown]
# 연습

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(df['loss'], 'b-', label='loss')
plt.plot(df['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(df['accuracy'], 'g-', label='accuracy')
plt.plot(df['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %%
Group = ['E1_G6', 'E2_G11', 'E3_G20']
Group_values = [0.918, 0.891, 0.857]

plt.figure(figsize=(7, 5))
plt.bar(Group, Group_values, color='g', alpha=0.6)

for i, name in enumerate(Group):
    plt.text(name, Group_values[i], "{:.3f}".format(Group_values[i]),
             fontsize = 14, 
             color='blue',
             horizontalalignment='center',
             verticalalignment='bottom')

plt.ylim(0.7, 1.0)

plt.show()
